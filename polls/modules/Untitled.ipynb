# %%
from EncuestasSQL import EncuestasDB
import pandas as pd

# %%
dgae = pd.read_excel("files/dgae.xlsx")

# %%
enc = EncuestasDB(dgae)
act = enc.repIndividual()
# Out:
# C:\Users\hrangel\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#  EncuestasDB del PVE Comit 1.2.7
# Actualized
# C:\Users\hrangel\Documents\Django\djangotest\polls\modules\EncuestasSQL.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reporte=reporte.append({
# C:\Users\hrangel\Documents\Django\djangotest\polls\modules\EncuestasSQL.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reporte=reporte.append({
# ...

# %%
act.to_excel('V:/1TRABAJOS/2019/contestadas_28_09_22.xlsx')
